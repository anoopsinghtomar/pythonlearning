# %% [markdown]
# ## Vibium script steps Vibium
# 1. Install Python
# 2. Create a Project Folder
# 3. Install vibium <br>
#     %pip install vibium
# 4. Write Vibium Script & Run it
#
# ## What Just Happened?
#
# | Line | What It Does |
# |-----|-------------|
# | `browser.launch()` | Opens Chrome |
# | `vibe.go(url)` | Navigates to a URL |
# | `vibe.screenshot()` | Captures the page as PNG bytes |
# | `vibe.find(selector)` | Finds an element by CSS selector |
# | `link.text()` | Gets the element's text content |
# | `link.click()` | Clicks the element |
# | `vibe.quit()` | Closes the browser |

# %%
# Install Vibium
# %pip install vibium
# Out:
# Collecting vibium
#   Downloading vibium-0.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting vibium-win32-x64>=0.1.0 (from vibium)
#   Downloading vibium_win32_x64-0.1.0-py3-none-any.whl.metadata (659 bytes)
# Collecting websockets>=12.0 (from vibium)
#   Downloading websockets-15.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading vibium-0.1.0-py3-none-any.whl (10 kB)
# Downloading vibium_win32_x64-0.1.0-py3-none-any.whl (1.5 kB)
# Downloading websockets-15.0.1-py3-none-any.whl (169 kB)
# Installing collected packages: websockets, vibium-win32-x64, vibium
#
#    ---------------------------------------- 0/3 [websockets]
#    ---------------------------------------- 0/3 [websockets]
#    ---------------------------------------- 0/3 [websockets]
#    ---------------------------------------- 0/3 [websockets]
#    ---------------------------------------- 0/3 [websockets]
#    -------------------------- ------------- 2/3 [vibium]
#    -------------------------- ------------- 2/3 [vibium]
#    ---------------------------------------- 3/3 [vibium]
#
# Successfully installed vibium-0.1.0 vibium-win32-x64-0.1.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from vibium import browser_sync as browser

# Launch a browser (you'll see it open!)
vibe = browser.launch()

# Go to a website
vibe.go("https://www.python.org/")
print("Loaded example.com")

# Take a screenshot
png = vibe.screenshot()
with open("screenshot.png", "wb") as f:
    f.write(png)
print("Saved screenshot.png")

# Find and click the link
link = vibe.find("a")
print("Found link:", link.text())
link.click()
print("Clicked!")

# Close the browser
vibe.quit()
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# ClickerNotFoundError                      Traceback (most recent call last)
# Cell In[3], line 4
#       1 from vibium import browser_sync as browser
#       3 # Launch a browser (you'll see it open!)
# ----> 4 vibe = browser.launch()
#       6 # Go to a website
#       7 vibe.go("https://www.python.org/")
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\vibium\browser_sync.py:130, in browser_sync.launch(headless, port, executable_path)
#     127 loop_thread = _EventLoopThread()
#     128 loop_thread.start()
# --> 130 vibe = loop_thread.run(
#     131     browser.launch(
#     132         headless=headless,
#     133         port=port,
#     134         executable_path=executable_path,
#     135     )
#     136 )
#     138 return VibeSync(vibe, loop_thread)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\vibium\browser_sync.py:39, in _EventLoopThread.run(self, coro)
#      37     raise RuntimeError("Event loop not started")
#      38 future = asyncio.run_coroutine_threadsafe(coro, self._loop)
# ---> 39 return future.result()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\concurrent\futures\_base.py:450, in Future.result(self, timeout)
#     448     raise CancelledError()
#     449 elif self._state == FINISHED:
# --> 450     return self.__get_result()
#     451 else:
#     452     raise TimeoutError()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\vibium\browser.py:35, in browser.launch(headless, port, executable_path)
#      19 @staticmethod
#      20 async def launch(
#      21     headless: bool = False,
#      22     port: Optional[int] = None,
#      23     executable_path: Optional[str] = None,
#      24 ) -> Vibe:
#      25     """Launch a new browser instance.
#      26
#      27     Args:
#    (...)     33         A Vibe instance for browser automation.
#      34     """
# ---> 35     process = await ClickerProcess.start(
#      36         headless=headless,
#      37         port=port,
#      38         executable_path=executable_path,
#      39     )
#      41     client = await BiDiClient.connect(f"ws://localhost:{process.port}")
#      43     return Vibe(client, process)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\vibium\clicker.py:170, in ClickerProcess.start(cls, headless, port, executable_path)
#     153 @classmethod
#     154 async def start(
#     155     cls,
#    (...)    158     executable_path: Optional[str] = None,
#     159 ) -> "ClickerProcess":
#     160     """Start a clicker process.
#     161
#     162     Args:
#    (...)    168         A ClickerProcess instance.
#     169     """
# --> 170     binary = executable_path or find_clicker()
#     172     # Ensure Chrome is installed (auto-download if needed)
#     173     ensure_browser_installed(binary)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\vibium\clicker.py:100, in find_clicker()
#      97 if cache_binary.is_file():
#      98     return str(cache_binary)
# --> 100 raise ClickerNotFoundError(
#     101     f"Could not find clicker binary. "
#     102     f"Install the platform package: pip install {package_name}"
#     103 )
#
# ClickerNotFoundError: Could not find clicker binary. Install the platform package: pip install vibium_win32_x64
